# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Ejercicio 1
#
# Obtener las primeras `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución, aquí tu respuesta
df.head(3)
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí

# %% [markdown]
# # Ejercicio 2
#
# Obtener las últimas `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
#df.tail(3)
df[-3:] #así cogería los 3 registros empezando por atrás.
# no le ponemos el registro final -1 pq en el rango, el último no lo coge.
# Out:
#    nombre  puntaje  intentos califico
# h   Edgar      NaN         1       No
# i   Angie      8.0         2       No
# j  Irlesa     18.0         1       Sí

# %% [markdown]
# # Ejercicio 3
#
# Seleccionar las columnas ['nombre', 'califico'] de un objeto `DataFrame`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Lista_columnas = ['nombre', 'califico']
#df[Lista_columnas]
df[['nombre', 'califico']]
# Out:
#     nombre califico
# a    Oliva       Sí
# b  Daniela       No
# c     Juan       Sí
# d   Germán       No
# e   Edward       No
# f     Alex       Sí
# g    Julio       Sí
# h    Edgar       No
# i    Angie       No
# j   Irlesa       Sí

# %% [markdown]
# # Ejercicio 4
#
# Comprobar si este objeto `DataFrame` está vacío con `empty`.

# %%
df = pd.DataFrame({'X': []})

df.empty
# Out:
# True

# %% [markdown]
# # Ejercicio 5
#
# Crear un objeto `DataFrame` a partir de objetos `Series`.
# Las series son lo mismo que las listas, pero mejoradas. Una columna de una tabla es una serie. Un DataFrame está hecho de series.

# %%
#Partimos de dos series
nombres = pd.Series(['Edward', 'Germán', 'Daniela'])
edades = pd.Series([27, 23, 19])

# %%
#1. Metemos las series en un diccionario

#2. Metemos el diccionario dentro de un dataframe

# %% [markdown]
# # Ejercicio 6
#
# Determinar los datos en un `DataFrame` que son nulos (NaN).

# %%
nombres = ['Edward', 'Daniela', 'Germán']
edades = [5, 6, np.nan]
fecha_nacimiento = [pd.Timestamp('1990-01-03'), None, np.nan]

personas = {'nombre': nombres, 'edad': edades, 'fecha_nacimiento': fecha_nacimiento}

df = pd.DataFrame(data=personas)

df
# Out:
#     nombre  edad fecha_nacimiento
# 0   Edward   5.0       1990-01-03
# 1  Daniela   6.0              NaT
# 2   Germán   NaN              NaT

# %%
#df.isnull().values.any()
df.isnull()
# Out:
#    nombre   edad  fecha_nacimiento
# 0   False  False             False
# 1   False  False              True
# 2   False   True              True

# %% [markdown]
# # Ejercicio 7
#
# Modificar un valor o entrada específico de un objeto `DataFrame` usando `loc`.
# ¿Cómo funciona loc? nombredelDataFrame.loc['fila','columna'] nos localiza un dato situado en un cruce de fila x columna.
# Si quiero seleccionar dos filas, en el lugar de la 'fila' le ponemos una lista formada por las dos filas, es decir, ['filaa', filab'] que sería df.loc[['filaa', 'filab'], 'columna']. Si quiero todas las filas de dos columnas ponemos df.loc[:,['columna1', 'columna2']]
# Una vez localizado el valor, podemos reemplazarlo simplemente escribiendo igual = y el nuevo valor.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %%
df.loc['a','Y'] = 99
df
# Out:
#    X   Y   Z
# a  1  99   2
# b  2   4   3
# c  3   3   5
# d  4   2   7
# e  5   1  11

# %% [markdown]
# # Ejercicio 8
#
# Acceder a un valor o entrada específico de un objeto `DataFrame` usando `loc`.
# También podemos usar iloc (loc indexado), si quiero seleccionar utilizando el número de fila o de columna en lugar de su nombre. Hay que tener en cuenta que python empieza a contar en 0 y no coge el último valor de una lista...
# Si sólo le ponemos un dato son las filas. Por ejemplo, df.iloc[1], trae la fila 1. Si quiero varias hay que hacer una lista: df.iloc[[1, 3, 4]]. Si quiero un intervalo df.iloc[3:5].
# Si quiero solo un dato, una intersección df.iloc[numerofila,numerocolumna]
# Para coger columnas df.iloc[:, 2] (cogería todas las filas de la columna 2 (que es la tercera)

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %%
df.loc['d', 'Y']
# Out:
# 2

# %% [markdown]
# # Ejercicio 9
#
# Sumar los valores de la columna intentos con `sum`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
Suma_intentos = df["intentos"].sum()
print (Suma_intentos)
# Out:
# 19

# %% [markdown]
# # Ejercicio 10 (Opcional)
#
#  Agregar una nueva fila a un objeto `DataFrame` por medio de `loc`.
#  Si seleccionamos una fila que no existe, nos la crea.
#  df.loc['nombrenuevafila'] = ['valor1', 'valor2', 'valor3', 'valor4'] tantos valores como columnas tenga la tabla.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %% [markdown]
# # Ejercicio 11
#
# Eliminar una fila de un `DataFrame` con la función `drop`.
# Nombre_de_la_nueva_df = df.drop('nombredelafila'). Podemos borrar dos filas creando una lista, poniendo sus nombres dentro de corchetes, entre comillas y separados por coma. Ejemplo new_df = df.drop([fila1, fila2])
# Si son columnas lo que queremos eliminar, tenemos que escribir df.drop(columns=['nombrecolumna1', 'nombrecolumna2'])

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
new_df = df.drop(['i', 'j'])
print (new_df)
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No

# %% [markdown]
# # Ejercicio 12
#
# Mostrar los n primeros y últimos registros de un objeto `DataFrame` con `head` y `tail`.

# %%
datos_1 = list(range(1, 101))
datos_2 = list(range(1, 101))

df = pd.DataFrame({'A': datos_1, 'B': datos_2})

df
# Out:
#       A    B
# 0     1    1
# 1     2    2
# 2     3    3
# 3     4    4
# 4     5    5
# ..  ...  ...
# 95   96   96
# 96   97   97
# 97   98   98
# 98   99   99
# 99  100  100
#
# [100 rows x 2 columns]

# %% [markdown]
# # Ejercicio 13
#
# Agregar una nueva columna a un `DataFrame` con notación de slicing.
#
# `df['nombre_nueva_columna'] = valores`

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
#Valores nueva columna
colores = ['Negro', 'Blanco', 'Azul', 'Verde', 'Rojo', 'Amarillo',
           'Gris', 'Naranja', 'Lila', 'Café']

# %% [markdown]
# # Recorrer un df
#
#  Para iterar cada una de las filas de un `DataFrame` utilizamos la función `iterrows`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
for indice, fila in df.iterrows():
    print(fila['nombre'], fila['califico'])

# %% [markdown]
# # Ejercicio 14 (Opcional)
#
# Obtener como una lista Python los nombres de las columnas de un `DataFrame`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

df = pd.DataFrame(datos)

df

# %% [markdown]
# # Ejercicio 15
#
# Renombrar las columnas de un objeto `DataFrame` a partir del diccionario dado.

# %%
datos = {'Columna1': [1, 2, 3, 4, 5], 'Columna2': [5, 4, 3, 2, 1],
         'Columna3': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df

# %%
#Diccionario con los nuevos nombres de las columnas
renombrado_columnas = {'Columna1': 'X', 'Columna2': 'Y', 'Columna3': 'Z'}

# %% [markdown]
# # Ejercicio 16
#
# * Guardar los registros de un `DataFrame` en un archivo de formato **CSV**.
# * Prueba a descargarlos en tu PC.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí
